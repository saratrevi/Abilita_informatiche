# %%
# !pip install emcee
# Out:
# Requirement already satisfied: emcee in c:\users\sara trevisan\anaconda3\lib\site-packages (3.1.4)
# Requirement already satisfied: numpy in c:\users\sara trevisan\anaconda3\lib\site-packages (from emcee) (1.21.6)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy.io import fits
import emcee

# %%
hdul1 = fits.open("C:/Users/Sara Trevisan/Downloads/SPT-CL_J2344-4243/SPT-CL_J2344-4243_band3_combined.dat.im.image.fits")
hdul2 = fits.open("C:/Users/Sara Trevisan/Downloads/SPT-CL_J2344-4243/SPT-CL_J2344-4243_band3_combined.jac.im.image.fits")

# %%
num_hdus = len(hdul1)
print(f"Numero di HDU nel file FITS: {num_hdus}")

data = hdul1[0].data
noise = hdul2[0].data

print(f"Dimensioni dei dati: {data.shape}")
print(f"Tipo di dati: {data.dtype}")
print(f"Dimensioni dei dati 2: {noise.shape}")
print(f"Tipo di dati 2: {noise.dtype}")
# Out:
# Numero di HDU nel file FITS: 1
# Dimensioni dei dati: (2048, 2048)
# Tipo di dati: >f4
# Dimensioni dei dati 2: (2048, 2048)
# Tipo di dati 2: >f4

# %%
plt.imshow(data, cmap='viridis', origin='lower')  
plt.colorbar()
plt.title('FITS Data')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
plt.imshow(noise, cmap='viridis', origin='lower')
plt.colorbar()
plt.title('FITS noise')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
#cerco gli estremi per le coordinate x e y 
valid_pixel_coordinates = np.argwhere(~np.isnan(data))

x_coordinates = valid_pixel_coordinates[:, 1]
y_coordinates = valid_pixel_coordinates[:, 0]


min_x = np.min(x_coordinates)
max_x = np.max(x_coordinates)
min_y = np.min(y_coordinates)
max_y = np.max(y_coordinates)

print("Minimum X (with valid data):", min_x)
print("Maximum X (with valid data):", max_x)
print("Minimum Y (with valid data):", min_y)
print("Maximum Y (with valid data):", max_y)
# Out:
# Minimum X (with valid data): 528
# Maximum X (with valid data): 1520
# Minimum Y (with valid data): 510
# Maximum Y (with valid data): 1538

# %%
x = np.arange(data.shape[1])
y = np.arange(data.shape[0]) 

fixed_beta = 0.8  

# guess iniziale 
initial_guess = [1025, 1020, -0.00003, 4.5]

# %%
# maschero i nan value nelle immagini

nan_mask = np.isnan(data)
nan_flag = np.zeros_like(data, dtype=bool)
nan_flag[nan_mask] = True

data_masked = np.ma.masked_array(data, mask=nan_flag)


nan_mask2 = np.isnan(noise)
nan_flag2 = np.zeros_like(noise, dtype=bool)
nan_flag2[nan_mask2] = True

noise_masked = np.ma.masked_array(noise, mask=nan_flag2)

# %%
# definizione del modello 
def beta_model(params, x, y):
    x0, y0, n0, rc = params
    beta = fixed_beta 
    r_squared = (x - x0)**2 + (y - y0)**2
    model = n0 * (1 + r_squared / rc**2)**(-3 * beta / 2)
    return model

# %%
def log_prior(params):
    x0, y0, n0, rc = params
    # print("log_prior params:", params)
    # Define your priors here, e.g., uniform priors
    if min_x < x0 < max_x and min_y < y0 < max_y and -1.0 < n0  and 0 < rc < 300:
        return 0.0  
    return -np.inf

# %%
# def log_likelihood(params, x, y, data1, noise_estimate):
#     model = beta_model(params, x, y)
#     residual = data1 - model
#     noise_estimate += 1e-10
#     logl = np.sum(np.log(1. / np.sqrt(2 * np.pi * noise_estimate**2)) - (residual**2) / (2. * noise_estimate**2))
#     print("logl:", logl)
#     return logl
#def log_likelihood(params, x, y, data, noise):
#    model = beta_model(params, x, y)
#    residual = data - model
#    logl = np.sum(-0.5 * np.log(2 * np.pi * noise**2) - 0.5 * (residual**2) / noise**2)
#    # print("logl:", logl)
#    return logl
def log_likelihood(params, x, y, data, noise):
    model = beta_model(params, x, y)
    residual = data - model
    masked_residual = np.ma.masked_array(residual, mask=noise.mask)
    logl = np.sum(-0.5 * np.log(2 * np.pi * noise**2) - 0.5 * (masked_residual**2) / noise**2)
    # print("logl:", logl)
    return logl

# %%
def log_posterior(params, x, y, data, noise):
    lp = log_prior(params)
    if not np.isfinite(lp):
        return -np.inf
    logl = log_likelihood(params, x, y, data, noise)
    return logl + lp

# %%
# Definisco il numero di parametri e di walkers 
nwalkers, ndim = 16, 4

#pos = [initial_guess] + 1e-6 * np.random.randn(nwalkers, ndim)
pos = [initial_guess] + [1, 1, 1e-6, 1e-2] * np.random.randn(nwalkers, ndim)

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, log_posterior, args=(x, y, data_masked, noise_masked))

# %%
# Run the MCMC sampler
n_steps = 300
sampler.run_mcmc(pos, n_steps, progress=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 300/300 [53:07<00:00,  8.79s/it]
# State([[ 1.02080009e+03  1.01807621e+03 -2.72648885e-05  4.59771983e+00]
#  [ 1.02102193e+03  1.02091070e+03 -2.44166169e-05  4.47238652e+00]
#  [ 1.02082202e+03  1.01809436e+03 -2.72759230e-05  4.58387380e+00]
#  [ 1.02077282e+03  1.01814993e+03 -2.69452101e-05  4.57218667e+00]
#  [ 1.02075197e+03  1.01820626e+03 -2.67096795e-05  4.54654172e+00]
#  [ 1.02081516e+03  1.01805401e+03 -2.73850439e-05  4.61569776e+00]
#  [ 1.02076940e+03  1.01816435e+03 -2.69060190e-05  4.57053651e+00]
#  [ 1.02062292e+03  1.01821428e+03 -2.66356288e-05  4.43903171e+00]
#  [ 1.02073737e+03  1.01820575e+03 -2.68059149e-05  4.49024333e+00]
#  [ 1.02080556e+03  1.01809135e+03 -2.72050127e-05  4.60333672e+00]
#  [ 1.02080985e+03  1.01809314e+03 -2.72642531e-05  4.59753727e+00]
#  [ 1.02020340e+03  1.02200149e+03 -2.72350291e-05  4.45915612e+00]
#  [ 1.02079717e+03  1.01814401e+03 -2.70786088e-05  4.56813725e+00]
#  [ 1.02004009e+03  1.02198244e+03 -2.71834485e-05  4.44956277e+00]
#  [ 1.02077146e+03  1.01813951e+03 -2.70055134e-05  4.56238783e+00]
#  [ 1.02064605e+03  1.01828484e+03 -2.61471638e-05  4.55895092e+00]], log_prob=[-1.94312256e+11 -1.94372571e+11 -1.94312257e+11 -1.94312072e+11
#  -1.94312083e+11 -1.94312083e+11 -1.94311925e+11 -1.94311538e+11
#  -1.94311921e+11 -1.94312221e+11 -1.94311924e+11 -1.94386535e+11
#        1747560060, 2720360122,  900793099,  799336327, 4113316663,
#        2603906064, 3608151478, 3889350367, 1270661743, 2807691579,
#        1319633414,  160428517, 2079598795,  972681380, 3241988442,
#        3028711686, 2454005739, 1426959804, 3403952038, 3729912215,
#        1999202255, 4121684080, 2581055566,   92858179,  995123528,
#        3956153884, 3455603963,  332583275, 1402243052,  951865982,
#        2199077708,  646347242,  972089495, 3568783997, 1976393504,
#        3320829330, 1598732823, 1355434620, 3214813531, 1330006209,
#         298679387, 3072411607, 3365778177, 2846445995, 1438794352,
#        3017349133, 1238624835, 3463484426, 4213579232,  980816701,
#        2285941459,  864372442, 1740402896, 2992236132, 2972940846,
#        1825614346, 3436771865, 1427507673, 4070727774, 3420971639,
#        1873573398, 1849792010, 1530555523, 1759116888, 3196042185,
#        2483166242,  689679451, 3750130542, 1083664937, 3059434917,
#        1203784567, 1875088129, 1318897122, 3122029168, 1588234557,
#         373547904, 2871292111, 2688116707,  596006714, 1180834598,
#         763786229, 1216197132,  141712953, 3832022045,  341804652,
#        3861170708,  432125090, 2555673095, 4279048939,  647645569,
#         547269242, 2440089019, 1252294357, 3754742599, 3711995367,
#        3195685794, 1689902561,  928583056, 1698121640, 1518476111,
#        2355534819, 3644371620, 1696373187,  290437713, 3604758554,
#        3384508039, 1069802276,  868498215, 1491985015, 1179696529,
#         839215518, 3372520198, 3988064866, 1864204879, 2746735257,
#         909568308, 1516134442, 1391299689, 3295749980, 4086709017,
#        1099539494, 3818697163, 1566595579, 3016041794, 1496624135,
#        2375395457, 3805954322, 4179444203, 2145988341, 3175618040,
#         340728466, 2496004470, 3921999045, 2660714226, 2956508918,
#        2824104048,   94550677, 1923434922, 1884172603, 3319038369,
#        2174994686, 1731614968, 2862101753,  608712437, 2721339715,
#         914144614,  427544805, 1783392082, 2409997406], dtype=uint32), 573, 0, 0.0))

# %%
fig, axes = plt.subplots(4, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
print(samples.shape)
labels = ["x_0", "y_0", "n0", "rc"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number");
# Out:
# (300, 16, 4)

# %%
best_fit_params = sampler.get_chain(discard=100, flat=True)[np.argmax(sampler.get_blobs(flat=True, discard=100))]

# %%
# genero immagine dato il best fit dei parametri 
model_predictions = np.zeros_like(data)
for i in range(data.shape[0]):
    for j in range(data.shape[1]):
        model_predictions[i, j] = beta_model(best_fit_params, i, j)

# predizione del modello - dati iniziali 
subtracted_data = data - model_predictions


fits.writeto("subtracted_image.fits", subtracted_data,  overwrite=True)

# %%
subtracted_image = fits.getdata("subtracted_image.fits")

plt.imshow(subtracted_image, cmap="viridis")
plt.colorbar()
plt.title("Subtracted Image")
plt.show()

# %%
center_x = 1020
center_y = 1018
width = 50
height = 50

cropped_image = subtracted_image[center_y - height // 2:center_y + height // 2, center_x - width // 2:center_x + width // 2]

plt.imshow(cropped_image, cmap="viridis")
plt.colorbar()
plt.title(" data-model")
plt.show()

# %%
cropped_data = data[center_y - height // 2:center_y + height // 2, center_x - width // 2:center_x + width // 2]

plt.imshow(cropped_data, cmap="viridis")
plt.colorbar()
plt.title("initial data")
plt.show()
